# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

load_dotenv("../.env")

client = OpenAI(api_key=os.environ['LLM_API_KEY'])

MODEL_NAME = "gpt-4o-mini"

# %%
messages=[]

while(True):
    message = input("メッセージを入力:")
    if message.strip()=="":
        break
    print(f"質問:{message}")

    messages.append({"role": "user", "content": message.strip()})
    if len(messages) > 8:
        del_message = messages.pop(0)

    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)

    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:今学ぶべきプログラミング言語といえば？
# 今学ぶべきプログラミング言語はいくつかありますが、特に注目されているのは以下の言語です：
#
# 1. **Python**: データサイエンス、機械学習、ウェブ開発、自動化など幅広い分野で使用されています。学びやすく、豊富なライブラリが揃っています。
#
# 2. **JavaScript**: ウェブ開発に欠かせない言語で、フロントエンド（React、Vue.jsなど）やバックエンド（Node.js）でも使用されます。
#
# 3. **Rust**: 高いパフォーマンスとメモリ安全性を持つ言語で、システムプログラミングやWebAssemblyの分野で人気が高まっています。
#
# 4. **Go**: Googleが開発した言語で、並行処理に強く、マイクロサービスアーキテクチャによく使われています。シンプルな構文が特徴です。
#
# 5. **Kotlin**: Android開発においてJavaに代わって人気が高まっている言語です。モダンな機能があり、使いやすさが魅力です。
#
# 6. **TypeScript**: JavaScriptのスーパーセットであり、大規模なアプリケーションの開発に適しています。コードの可読性や保守性を向上させることができます。
#
# 学ぶべき言語は、あなたの興味や目指したいキャリアに依存します。それぞれの言語には異なる分野での需要や特性があるので、目的に応じて選ぶと良いでしょう。
# ---ご利用ありがとうございました！---
