# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

load_dotenv()

client = OpenAI(api_key=os.environ['LLM_API_KEY'])

MODEL_NAME = "gpt-4o-mini"

# %%
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='売上データ')

# %%
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"

# %%
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"

response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# %%
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])
df_out.to_excel("売上データ分析結果.xlsx", index=False)
# Out:
#                                                    結果
# 0                       売上データを分析するために、以下の観点から傾向を述べます。
# 1
# 2                                     ### 1. カテゴリー別分析
# 3   - **食品**: 食品カテゴリは全体的に高い売上を記録しており、特に1月初めに売上が集中し...
# 4   - **衣服**: 衣服カテゴリには単価が高い商品（例: ジーンズ、Tシャツ）が存在し、売上...
# 5   - **日用品**: 日用品は他のカテゴリに比べて平均単価が低めですが、リピート購入が期待で...
# 6
# 7                                       ### 2. 売上日別分析
# 8   - 売上日は明らかに特定のタイミング（初売りや季節の変わり目）に集中していることがあります。...
# 9
# 10                                    ### 3. 単価と数量の関係
# 11  - 単価が高い商品（例: 衣服）は売上が高いですが、実際の売上数量は少ない傾向があります。逆...
# 12
# 13                                      ### 4. 利益率の分析
# 14  - 利益を原価から計算することで、各商品の利益率を見積もることができます。特に高単価の商品に...
# 15
# 16                                   ### 5. 時系列での売上傾向
# 17  - 期間を通じて売上が増加傾向にあるのか、また特定のダウンシーズンは存在するのかを分析するこ...
# 18
# 19                                             ### 結論
# 20  売上データから得られるインサイトは多岐にわたります。各カテゴリごとに売上動向を把握し、季節や...
