# %%
principal = int(input("元金を入力してください。"))
annual_interest_rate = int(input("年利(%)を入力してください。"))

for i in range(1, 11):
    principal = principal * (1 + (annual_interest_rate / 100))
    if i == 10:
        print(f"{i}年後の金額: {principal}")
# Out:
# 10年後の金額: 1628.8946267774422
