# %%
try:
    integer1 = int(input("整数を入力してください（1）"))
    integer2 = int(input("整数を入力してください（2）"))

    print(f"計算結果: {integer1 / integer2}")
except ZeroDivisionError:
    print("エラー: 0で割ることはできません")
except ValueError:
    print("エラー: 数値を入力してください")
# Out:
# エラー: 0で割ることはできません
