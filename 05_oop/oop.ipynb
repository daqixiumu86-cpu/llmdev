# %%
class Dog:
    species = "イヌ科イヌ属"

    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def bark(self):
        return f"{self.name}, {self.age}歳だよ。ワン!"

dog1 = Dog("ジョン", 3)
dog2 = Dog("ポチ", 5)
