# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

load_dotenv("../env")
os.environ['OPENAI_API_KEY'] = os.environ['LLM_API_KEY']

MODEL_NAME = "gpt-4o-mini"

# %%
chat_model = ChatOpenAI(
    model_name=MODEL_NAME,
    max_tokens=300,
    temperature=1.2
    )

system_prompt = "あなたはシステムエンジニアです。"
user_prompt = "言語モデルを使う上でのポイントは？"
messages = [
    SystemMessage(system_prompt),
    HumanMessage(user_prompt)
    ]

response = chat_model.invoke(messages)

print(response.content)
# Out:
# 言語モデルを効果的に使用するためのポイントはいくつかあります。以下に主要な点を挙げます。
#
# 1. **目的の明確化**: モデルを使用する目的やタスクを明確にする。例えば、文章生成、質問応答、要約、翻訳など。
#
# 2. **入力データの品質**: モデルに与える入力データが質の高いものであることを確認する。無関係な情報や手順を省くことで、精度を向上させる。
#
# 3. **プロンプトの工夫**: 効果的なプロンプト（入力文）を設計することで、望ましい出力を得やすくなる。具体的かつ明確な指示を提供することが重要。
#
# 4. **出力の検証**: モデルから得られる出力は必ずしも正確ではないため、結果を評価・検証するプロセスが必要。特に重要な決定に使う場合は注意が必要。
#
# 5. **バイアスの把握**: モデルは訓練データに基づいて学習するため、バイアスを含む可能性がある。この点に留意し、倫理的な観点からの評価を行う。
#
# 6. **
